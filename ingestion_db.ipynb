# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay0705/Vendor-Performance-Data-Analytics/blob/main/Vendor_Performance_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
# !pip install kaggle

# %%
import kagglehub
import pandas as pd

path = kagglehub.dataset_download(
    "shouryagupta01/vendor-performance-analysis"
)

print(path)
# Out:
# Using Colab cache for faster access to the 'vendor-performance-analysis' dataset.
# /kaggle/input/vendor-performance-analysis

# %%
import pandas as pd
import os

print(os.listdir(path))  # already done

df_purchases = pd.read_csv(os.path.join(path, "purchases.csv"))
df_purchases.head()
# Out:
# ['purchase_prices.csv', 'vendor_invoice.csv', 'purchases.csv', 'begin_inventory.csv', 'end_inventory.csv', 'sales.csv']
#            InventoryId  Store  Brand                   Description   Size  \
# 0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno  750mL
# 1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel  750mL
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 4           388  ATLANTIC IMPORTING COMPANY       8169  2023-12-24
# ...

# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

logging.basicConfig(
    filename ="logs/ingestion_db.log",
    level = logging.DEBUG,
    format = "%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a"
)

# %%
engine = create_engine('sqlite:///inventory.db')

# %%
path = "/root/.cache/kagglehub/datasets/shouryagupta01/vendor-performance-analysis/versions/1"

# %%
def load_raw_data():
    '''This function will load the CSVs at dataframe and ingest into db'''

    start = time.time()

    for file in os.listdir(path):
        if file.endswith(".csv"):
            df = pd.read_csv(os.path.join(path, file))
            logging.info(f'Ingesting {file} in db')
            ingest_db(df, file[:-4], engine)

    end = time.time()
    total_time = (end - start) / 60

    logging.info('------Ingestion Complete------')
    logging.info(f'\nTotal time taken: {total_time} minutes')

if __name__ =='__main__' :
  load_raw_data()

# %%
def ingest_db(df, table_name, engine):
    '''This function will ingest the dataframe into database table'''
    df.to_sql(
        table_name,
        con=engine,
        if_exists='replace',
        index=False
    )
